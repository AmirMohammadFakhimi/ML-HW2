# %% [markdown]
# <div>
# <img src='sharif_logo.png' alt="SUT logo" width=130 height=130 align=left class="saturate">
#
# <br>
# <font face="Times New Roman">
# <div dir=ltr align=center>
# <!-- <font color=0F5298 size=7> -->
# <font color=0F5298 size=6>
#     Introduction to Machine Learning <br> <br>
# <!-- <font color=2565AE size=5> -->
# <font size=5>
#     Computer Engineering Department <br>
#     Spring 2024 <br> <br>
# <font color=606060 size=5>
#     Homework 2: Practical - LDA, QDA & KNN <br> <br>
# <font color=686880 size=4>
#     TAs: Kasra Arabi, Amir Mohammad Fakhimi
#
# ____

# %% [markdown]
# ### Full Name :
# ### Student Number :
# ___

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_moons
from sklearn.decomposition import PCA

# %%
#!wget https://github.com/Kasraarabi/ML-HW2/blob/main/apple_quality.csv

# %% [markdown]
# # Sec 1: Exploration (15 points)

# %% [markdown]
# Load the dataset as a dataframe.

# %% [markdown]
# Display mean, standard deviation, min and max of each feature.

# %%
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %% [markdown]
# Remove Last Row, ID and Acidity.

# %% [markdown]
# Plot the distribution of each feature and identify the median value for both good and bad quality separately.

# %% [markdown]
# Plot the correlation matrix.

# %% [markdown]
# # Sec 2: Preprocessing (10 points)

# %% [markdown]
# Convert Quality column to a new binary column (having only 0 and 1 values). Then remove the original column.

# %% [markdown]
# Compute the number of outliners for each feature and remove them.

# %%
# Out:
#         Column       IQR  Lower Bound  Upper Bound Outliers
# 0         Size  2.622291    -5.750201     4.738963       22
# 1       Weight  2.042747    -5.075890     3.095097       54
# 2    Sweetness  2.540347    -5.548946     4.612442       32
# 3  Crunchiness  1.831470    -2.684440     4.641439       47
# 4    Juiciness  2.637262    -4.757179     5.791870       32
# 5     Ripeness  2.537889    -4.578510     5.573044       24
# 6      Quality  1.000000    -1.500000     2.500000        0
# Numbers of Outliers Removed : 211

# %% [markdown]
# # Sec 3: Training Models (25 points)

# %% [markdown]
# Convert the dataset (`x` and `y`) into numpy arrays, and split them into "training" and "testing" parts containing 80% and 20% of the data respectively.

# %% [markdown]
# Train both LDA and QDA models on the data using `sklearn`.

# %%
# Out:
# LinearDiscriminantAnalysis()

# %%
# Out:
# QuadraticDiscriminantAnalysis()

# %% [markdown]
# Implement LDA and QDA.

# %% [markdown]
# Linear Discriminant Analysis:

# %%
class LDA:
    """
    Fits it on data, then uses predict to get results.
    """

    def __init__(self):
        return self
    
    def fit(self, X, y):
        """Fit the training data
        Parameters
        ----------
        X : array-like, shape = [n_samples, n_features]
            Features
        y : array-like, shape = [n_samples, n_labels]
            Labels
        Returns
        -------
        self : object
        """

        n_samples, n_features = X.shape

        # TODO

        return self
    
    def predict(self, X):
        """ Predicts the value after the model has been trained.
        Parameters
        ----------
        X : array-like, shape = [n_samples, n_features]
            Features
        Returns
        -------
        Predicted value
        """
        n_samples, n_features = X.shape

        # TODO

        return self

# %% [markdown]
# Quadratic Discriminant Analysis:

# %%
class QDA:
    """
    Fits it on data, then uses predict to get results.
    """

    def __init__(self):
        return self
    
    def fit(self, X, y):
        """Fit the training data
        Parameters
        ----------
        X : array-like, shape = [n_samples, n_features]
            Features
        y : array-like, shape = [n_samples, n_labels]
            Labels
        Returns
        -------
        self : object
        """

        n_samples, n_features = X.shape

        # TODO

        return self
    
    def predict(self, X):
        """ Predicts the value after the model has been trained.
        Parameters
        ----------
        X : array-like, shape = [n_samples, n_features]
            Features
        Returns
        -------
        Predicted value
        """
        n_samples, n_features = X.shape

        # TODO
        
        return self

# %% [markdown]
# Train your models!

# %% [markdown]
# # Sec 4: Evaluation (10 points)

# %% [markdown]
# Using all 4 models, predict the labels for all samples belonging to the "testing" part.

# %%
# y_pred_sklda = 
# y_pred_skqda = 
# y_pred_lda = 
# y_pred_qda =

# %% [markdown]
# Calculate Accuracy, Precision, Recall, and F1-Score for your own models.

# %%
# Out:
# LDA:
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       407
#            1       0.70      0.74      0.72       355
#
#     accuracy                           0.73       762
#    macro avg       0.73      0.73      0.73       762
# weighted avg       0.73      0.73      0.73       762

# %%
# Out:
# QDA:
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82       407
#            1       0.79      0.81      0.80       355
#
#     accuracy                           0.81       762
#    macro avg       0.81      0.81      0.81       762
# weighted avg       0.81      0.81      0.81       762

# %% [markdown]
# Compute the ROC AUC Score using `sklearn`. (for both LDA and QDA models trained using this library.)

# %%
# Out:
# LDA:
# 0.7330103470948541

# %%
# Out:
# QDA:
# 0.8134962106793092

# %% [markdown]
# # Sec 5: Plotting Decision Boundaries Using Your Own Models (20 points)

# %% [markdown]
# Display data in 2 dimencions using PCA

# %%
def plot_decision_boundaries(X, y, classifier):
    """
    Plots decision boundaries for a classifier on 2D data.
    
    Parameters
    ----------
    X : array-like, shape = [n_samples, n_features]
        2D data after PCA transformation
    y : array-like, shape = [n_samples, ]
        Labels for the data
    classifier : Classifier instance
        An instance of a classifier from sklearn with a fit method
    """
    
    # TODO

# %% [markdown]
# Split the PCA transformed dataset (`x` and `y`) into "training" and "testing" parts containing 80% and 20% of the data respectively.

# %% [markdown]
# # LDA:

# %% [markdown]
# Initialize your LDA classifier and fit it on the PCA-transformed data

# %%
# Out:
# LinearDiscriminantAnalysis()

# %% [markdown]
# Now plot the decision boundaries of the LDA

# %% [markdown]
# # QDA:

# %% [markdown]
# Initialize your QDA classifier and fit it on the PCA-transformed data

# %% [markdown]
# Now plot the decision boundaries of the QDA

# %% [markdown]
# # Theoretical Insights (15 points)

# %% [markdown]
# Derive the mathematical formulation for the decision boundaries of LDA and QDA. Discuss how the eigenvectors and eigenvalues of the covariance matrices influence the shape and orientation of these boundaries.

# %% [markdown]
# Given the PCA transformation of the data, how does the change in basis affect the computational complexity and the discriminative power of LDA and QDA? Provide a theoretical justification for your answer.

# %% [markdown]
# # Sec 6: KNN

# %% [markdown]
# Implement KNN. (20 points)

# %%
def knn(training_x, training_y, testing_x, k):
    """
    K-Nearest Neighbors
    
    Parameters
    ----------
    training_x : array-like, shape = [n_samples, n_features]
        Training data
    training_y : array-like, shape = [n_samples, ]
        Training labels
    testing_x : array-like, shape = [n_samples, n_features]
        Testing data
    k : int
        Number of neighbors to use
    """
    
    # TODO
    return prediction

# %% [markdown]
# Test your KNN model on the dataset and report the accuracy. (5 points)

# %%
# load 10000 samples from make_moons dataset and a desired noise level
# TODO
X, y = [None] * 2

# split the dataset into training and testing parts
# TODO
x_train, x_test, y_train, y_test = [None] * 4

# %%
# Run Knn with k=3 on dataset and report its accuracy (you can use sklearn's accuracy_score)
# TODO
# Out:
# Accuracy: 0.9985

# %% [markdown]
# Implement plotting the decision boundary. (15 points)

# %%
def decision_boundary_plot(x_train, y_train, k):
    """
    Plots the decision boundary for KNN
    
    Parameters
    ----------
    x_train : array-like, shape = [n_samples, n_features]
        Training data
    y_train : array-like, shape = [n_samples, ]
        Training labels
    k : int
        Number of neighbors to use
    """
    
    # TODO
    plt.show()

# %% [markdown]
# Plot the decision boundary for KNN with k=[1, 3, 10, 50, 100] (5 points)

# %%
# TODO

# %% [markdown]
# # Interpret the results (5 points)

# %% [markdown]
# Why decision boundaries change in that way?
